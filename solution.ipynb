# %% [markdown]
# ### Two numbers X and Y are chosen between 1 and 0. What is the probability that X/Y will round to a even number.

# %% [markdown]
# Choosing two numbers between 0 and 1 is equavalent to choosing a point from [0,1] x [0,1] rectangle.

# %%
import matplotlib.pyplot as plt
import random

# %%
n = 1000
xPlot = [0]*n
yPlot = [0]*n

# %%
for i in range(n):
    x = random.uniform(0,1)
    y = random.uniform(0,1)
    rounded = round(x/y)
    if rounded%2 == 0: 
        xPlot[i] = x
        yPlot[i] = y

# %%
plt.plot(xPlot, yPlot, 'o', markersize=2)
plt.show()

# %% [markdown]
# The above plot suggests that the accepted points follow a pattern.

# %% [markdown]
# #### Lets Find the probability
# ![](https://quicklatex.com/cache3/83/ql_31ac6c6e9080e4b8e94207235f6a9e83_l3.png)

# %% [markdown]
# ![](https://quicklatex.com/cache3/05/ql_45652d3074dae45a1e28ca896e0c3f05_l3.png)

# %%
a = [0, 1]
b = [0, 0.5]

plt.plot(a, b, color='blue', label='Line 1')

plt.xlim(0, 1)
plt.ylim(0, 1)

plt.fill_between(a, b, color='lightblue', alpha=0.5)

plt.show()

# %% [markdown]
# ![](https://quicklatex.com/cache3/5d/ql_d91085195fc0f5990f9e3b7cac57ee5d_l3.png)

# %%
a1 = [0, 2/3]
b1 = [0, 1]

a2 = [0, 2/5]
b2 = [0, 1]

plt.plot(a, b, color="blue")
plt.fill_between(a, b, color='lightblue', alpha=0.5)
plt.plot(a1, b1, color="blue")
plt.plot(a2, b2, color="blue")
plt.fill_betweenx(b2, a2, a1, color='lightblue', alpha=0.5)
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ![](https://quicklatex.com/cache3/26/ql_7a470c143af411583dc3f56ac19b8526_l3.png)

# %%
a3 = [0, 2/7]
b3 = [0, 1]

a4 = [0, 2/9]
b4 = [0, 1]

plt.plot(a, b, color="blue")
plt.fill_between(a, b, color='lightblue', alpha=0.5)
plt.plot(a1, b1, color="blue")
plt.plot(a2, b2, color="blue")
plt.fill_betweenx(b2, a2, a1, color='lightblue', alpha=0.5)
plt.plot(a3, b3, color="blue")
plt.plot(a4, b4, color="blue")
plt.fill_betweenx(b4, a3, a4, color='lightblue', alpha=0.5)
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# And so on ...
# ##### The probability will be the area of shaded region.
# ![](https://quicklatex.com/cache3/94/ql_66ad9acaeb65ee31663c90cbc113a094_l3.png)

# %% [markdown]
# #### The probability found by solving is 0.4646 and by simulation is 0.464.
